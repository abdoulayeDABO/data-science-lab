# %%
# ============================================================
# Auteur      : Abdoulaye DABO
# Date        : 21/02/2025
# Contact     : abdoulayedabo@esp.sn
# Description : Tuto geopandas
# ============================================================

# %%
import geopandas as gpd
from geodatasets import get_path

path_to_data = get_path("nybb")
gdf = gpd.read_file(path_to_data)

gdf
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf.geometry.name
gdf.plot()
# Out:
# <Axes: >

# %%
# # Depuis un fichier local
gdf = gpd.read_file("../../data/gadm41_SEN_shp/gadm41_SEN_4.shp")
# gdf = gpd.read_file("senegal.geojson")

# Directement depuis une URL
# url = "https://raw.githubusercontent.com/.../senegal.geojson"
# gdf = gpd.read_file(url)

zipfile = "../../data/gadm41_SEN_1.json.zip"
states = gpd.read_file(zipfile)
states.plot(legend=True)


# gdf.head(1)
# Out:
# <Axes: >

# %%
# Voir les régions disponibles
print(gdf["NAME_1"].unique())

# Compter les communes par région
gdf.groupby("NAME_1")["NAME_4"].count()

# Filtrer uniquement Dakar
dakar = gdf[gdf["NAME_1"] == "Dakar"]
dakar.plot()
# Out:
# ['Dakar' 'Diourbel' 'Fatick' 'Kaffrine' 'Kaolack' 'Kédougou' 'Kolda'
#  'Louga' 'Matam' 'Saint-Louis' 'Sédhiou' 'Tambacounda' 'Thiès'
#  'Ziguinchor']
# <Axes: >

# %%
# import matplotlib.pyplot as plt

# # Carte de Dakar avec le nom des communes
# fig, ax = plt.subplots(figsize=(10, 10))
# dakar.plot(ax=ax, color="lightblue", edgecolor="black")

# # Ajouter les noms des communes
# dakar.apply(lambda row: ax.annotate(
#     row["NAME_4"],
#     xy=row.geometry.centroid.coords[0],
#     fontsize=7, ha="center"
# ), axis=1)

# plt.title("Communes de Dakar")
# plt.show()
