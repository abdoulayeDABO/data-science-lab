# %% [markdown]
# # Intro statistique

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('../data/FAO.xlsx')

# %%
# df.head()
# df.info()
# df.describe()
# df.columns
# df.shape
# df.dtypes
# Out:
#   Domain Code                        Domain  Area Code (M49)     Area  \
# 0         QCL  Crops and livestock products              686  Senegal
# 1         QCL  Crops and livestock products              686  Senegal
# 2         QCL  Crops and livestock products              686  Senegal
# 3         QCL  Crops and livestock products              686  Senegal
# 4         QCL  Crops and livestock products              686  Senegal
#
#    Element Code         Element  Item Code (CPC)       Item  Year Code  Year  \
# 0          5312  Area harvested           1211.0  Asparagus       1993  1993
# 1          5510      Production           1211.0  Asparagus       1993  1993
# 2          5312  Area harvested           1211.0  Asparagus       1994  1994
# 3          5510      Production           1211.0  Asparagus       1994  1994
# 4          5312  Area harvested           1211.0  Asparagus       1995  1995
#
#   Unit  Value Flag                  Flag Description Note       .1   .2
# ...

# %%
# Calculer la moyenne des valeur pour chaque annee
# moy_annee = df.filter(items=['Year', 'Value']).groupby('Year').mean()
# moy_annee = df.groupby('Year')['Value'].mean()
# print(moy_annee[:10])

# Calculer la moyenne des valeur pour chaque annee et element
# moy_annee_elt = df.groupby(['Year', 'Element'])['Value'].mean()
# # print(moy_annee_elt)

# # row = df.iloc[1]
# # print(row)
# # column = df["two"]
# # print(column)

# annees  = df.Year # Series
# print(type(annees))
# valeurs = df.Value

# for annee in annees:
#     idx = np.where(annees == annee)
    
#     # print(annee)
#     # print(idx)
