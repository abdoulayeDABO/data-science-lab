# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
image_path = "../data/Lenna.png"

# Load the image in color mode (default)
img_bgr = cv2.imread(image_path, cv2.IMREAD_COLOR)

# You can also load in grayscale
# img_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

if img_bgr is None:
    print("Error: Image not found or unable to read.")
else:
    # Display the image (creates a window)
    cv2.imshow("Image Window Title", img_bgr)
    cv2.waitKey(0) # Wait indefinitely until a key is pressed
    cv2.destroyAllWindows() # Close all image windows
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/plugins"
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# ...

# %%
# Informations utiles
print(f"Dimensions : {img_bgr.shape}")    
print(f"Type de données : {img_bgr.dtype}")    
print(f"Valeur min : {img_bgr.min()}")
print(f"Valeur max : {img_bgr.max()}")

# Afficher la matrice complète
print("Matrice de l'image :")
print(img_bgr)

# # Séparer les 3 canaux
# b, g, r = cv2.split(img_bgr)

# # Afficher un seul canal → apparaît en GRIS
# cv2.imshow('Canal Bleu seul', b)   # gris !!
# cv2.imshow('Canal Vert seul', g)   # gris !!
# cv2.imshow('Canal Rouge seul', r)  # gris !!

# cv2.waitKey(0)
# Out:
# Dimensions : (512, 512, 3)
# Type de données : uint8
# Valeur min : 3
# Valeur max : 255
# Matrice de l'image :
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  ...
#
#  [[ 60  18  84]
#   [ 60  18  84]
#   [ 58  27  92]
#   ...
#   [ 84  73 173]
#   [ 76  68 172]
#   [ 79  62 177]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]]
# -1

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import numpy as np

mat_1 = img_bgr[:, :, 0]
# print(mat_1)

cv2.imshow("Matrice 1",  mat_1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Su l'image correspondante seul la couleur grise est visible.

# %%
img_mat_1  = np.zeros_like(img_bgr)
img_mat_1[:, :, 0] = mat_1

cv2.imshow("Matrice 1",  img_mat_1)
cv2.waitKey(0)
cv2.destroyAllWindows()


# Su l'image correspondante seul la couleur bleu est visible.
# Out:
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mdialloc19/Bureau/Abdoulaye/python/data-science-lab/.venv/lib/python3.10/site-packages/cv2/qt/fonts.
# ...

# %%
img = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Calculer l'histogramme
hist = cv2.calcHist([img_bgr], [0], None, [256], [0, 256])

# Afficher
plt.plot(hist)
plt.xlabel('Intensité (0=noir, 255=blanc)')
plt.ylabel('Nombre de pixels')
plt.title('Histogramme')
plt.show()

# Mesurer le contraste
# std = np.std(img_bgr)
# print(f"Écart-type = {std}")
# Out:
# [ WARN:0@2476.714] global loadsave.cpp:278 findDecoder imread_('image.jpg'): can't open/read file: check file path/integrity
# Écart-type = 58.983724593480176

# %%
# Generate a random image
height, width, channels = 256, 512, 3
# Generate random pixel values in the range [0, 255] for an RGB image
random_image = np.random.randint(0, 256, (height, width, channels), dtype=np.uint8)

# Save the image using OpenCV
output_filename = 'random_image.png'
cv2.imwrite(output_filename, random_image)

# %%
import timeit
kernel_size = (15, 15)
# Blur on a grayscale image
def grayscale_process():
    blurred_image15g = cv2.GaussianBlur(grayscale_image, kernel_size, 0)
# Blur on a RGB image
def rgb_process():
    blurred_image15g = cv2.GaussianBlur(image, kernel_size, 0)

# Measure execution times
time_gray = timeit.timeit(grayscale_process, number=10)
time_rgb = timeit.timeit(rgb_process, number=10)

print(f"Execution time for Grayscale: {time_gray / 10:.6f} seconds")
print(f"Execution time for RGB: {time_rgb / 10:.6f} seconds")
